# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
#load spectrum
with open('./Plot3/spec_Region12_1.dat', 'r') as f:
    extent = array(f.readline().split(' '), float)
    spec_0 = loadtxt(f);
    spec_0 = transpose(spec_0, (1,0))
    spec_0 = flipud(spec_0)
    
with open('./Plot3/spec_Region12_4.dat', 'r') as f:
    extent = array(f.readline().split(' '), float)
    spec_1 = loadtxt(f);
    spec_1 = transpose(spec_1, (1,0))
    spec_1 =  flipud(spec_1)
    
    
with open('./Plot3/spec_Region12_3.dat', 'r') as f:
    extent = array(f.readline().split(' '), float)
    spec_2 = loadtxt(f);
    spec_2 = transpose(spec_2, (1,0))
    spec_2 =  flipud(spec_2)

# %%
#load harmonic spectra
with open ('./Plot3/Spec0.dat', 'r') as s0:
    spec0 = loadtxt(s0)
with open ('./Plot3/Spec3.dat', 'r') as s1:
    spec1 = loadtxt(s1)
with open ('./Plot3/Spec1.dat', 'r') as s2:
    spec2 = loadtxt(s2)

spec0[:, 1] = spec0[:, 1]/amax(spec0[:, 1])
spec1[:, 1] = spec1[:, 1]/amax(spec1[:, 1])
spec2[:, 1] = spec2[:, 1]/amax(spec2[:, 1])

# %%
figsize(38,15)
fig = figure()
ax1 = subplot2grid((2, 20), (0, 0),colspan = 14)
ax1.imshow(log10(spec_0), extent=[-3,3,0,1.5], cmap=cm.jet, vmin=-10, vmax=2)
ax1.set_xlabel('$p_z$ (a.u.)', size=30)
ax1.set_ylabel('$p_x$ (a.u.)', size=30)
Xscale=linspace(-3, 3, 7)
ax1.set_xticks(Xscale)
ax1.set_xticklabels(('-3','-2','-1','0','1','2','3'), size = 25)
Yscale=linspace(0, 1.5, 6)
ax1.set_yticks(Yscale)
ax1.set_yticklabels(('0','0.3','0.6','0.9','1.2','1.5'), size = 25)
ax1.text(-2.95, 1.35, '(a1)', fontsize = 30, color='w')
ax1.set_title(r'Momentum Distribution', size = 35)

ax2 = subplot2grid((2, 20), (0, 15), colspan = 3)
ax2.plot(spec0[:, 0] * 41300 / (2*pi), log(spec0[:, 1]), color = 'r', linewidth = 3)
Yscale=linspace(-4, 0, 5)
ax2.set_yticks(Yscale)
ax2.set_yticklabels(('-4','-3','-2','-1','0'), size = 25)
Xscale=linspace(0, 750, 3)
ax2.set_xticks(Xscale)
ax2.set_xticklabels(('0','375','750'), size = 25)
ax2.set_xlim(-180,950)
ax2.set_ylim(-4.3,0.1)
ax2.set_xlabel('Frequency (THz)', size = 30)
ax2.set_ylabel('Amplitude (arb.unit)', size = 30)
ax2.grid(True, linestyle = '-.')
ax2.axvspan(-180, 180, facecolor='silver', alpha=0.3)
ax2.axvspan(180, 575, facecolor='r', alpha=0.3)
ax2.axvspan(575, 950, facecolor='deepskyblue', alpha=0.3)
#ax3.axvspan(950, 1300, facecolor='darkviolet', alpha=0.3)
#ax2.text(-70, -4.2, 'THz', fontsize = 30)
#ax2.text(250, -4.2, '800nm', fontsize = 30)
#ax2.text(650, -4.2, '400nm', fontsize = 30)
ax2.text(-90, -4.2, 'THz', fontsize = 28)
ax2.text(190, -4.2, '800nm', fontsize = 28)
ax2.text(590, -4.2, '400nm', fontsize = 28)
#ax3.text(970, -4.2, '266nm', fontsize = 20)
ax2.text(-170, -0.25, '(a2)', fontsize = 35)
#legend = ax2.legend(loc='upper right', shadow=True, fontsize='large')
#legend.get_frame().set_alpha(0.2)
ax2.set_title('Spectrum', size = 35)

ax3 = subplot2grid((2, 20), (1, 0),colspan = 14)
ax3.imshow(log10(spec_1), extent=[-3,3,0,1.5], cmap=cm.jet, vmin=-10, vmax=2)
ax3.set_xlabel('$p_z$ (a.u.)', size=30)
ax3.set_ylabel('$p_x$ (a.u.)', size=30)
Xscale=linspace(-3, 3, 7)
ax3.set_xticks(Xscale)
ax3.set_xticklabels(('-3','-2','-1','0','1','2','3'), size = 25)
Yscale=linspace(0, 1.5, 6)
ax3.set_yticks(Yscale)
ax3.set_yticklabels(('0','0.3','0.6','0.9','1.2','1.5'), size = 25)
ax3.text(-2.95, 1.35, '(b1)', fontsize = 30, color='w')
#ax3.set_title(r'Momentum Distribution', size = 35)

ax4 = subplot2grid((2, 20), (1, 15), colspan = 3)
ax4.plot(spec1[:, 0] * 41300 / (2*pi), log(spec1[:, 1]), color = 'r', linewidth = 3)
Yscale=linspace(-4, 0, 5)
ax4.set_yticks(Yscale)
ax4.set_yticklabels(('-4','-3','-2','-1','0'), size = 25)
Xscale=linspace(0, 750, 3)
ax4.set_xticks(Xscale)
ax4.set_xticklabels(('0','375','750'), size = 25)
ax4.set_xlim(-180,950)
ax4.set_ylim(-4.3,0.1)
ax4.set_xlabel('Frequency (THz)', size = 30)
ax4.set_ylabel('Amplitude (arb.unit)', size = 30)
ax4.grid(True, linestyle = '-.')
ax4.axvspan(-180, 180, facecolor='silver', alpha=0.3)
ax4.axvspan(180, 575, facecolor='r', alpha=0.3)
ax4.axvspan(575, 950, facecolor='deepskyblue', alpha=0.3)
#ax3.axvspan(950, 1300, facecolor='darkviolet', alpha=0.3)
ax4.text(-90, -4.2, 'THz', fontsize = 28)
ax4.text(190, -4.2, '800nm', fontsize = 28)
ax4.text(590, -4.2, '400nm', fontsize = 28)
#ax3.text(970, -4.2, '266nm', fontsize = 20)
ax4.text(-170, -0.25, '(b2)', fontsize = 35)
#legend = ax2.legend(loc='upper right', shadow=True, fontsize='large')
#legend.get_frame().set_alpha(0.2)
#ax4.set_title('Spectrum', size = 35)

#savefig('Fig_3',dpi=512, bbox_inches='tight')
# Out:
# Text(-170, -0.25, '(b2)')

# %% [markdown]
# 去除title注释,突出太赫兹，弱化800 400，右边显示对数坐标。

# %%
import numpy as np
import matplotlib.pyplot as plt
nofont = {'fontname':'Times New Roman'}
Size = 16
plt.figure(figsize=(13, 5))
ax1 = plt.subplot2grid((2, 5), (0, 0), colspan=3)
extent = [-3,3,0,1.5]
ax1.imshow(np.log10(spec_0), cmap='jet', extent=extent,aspect='auto',vmin=-10, vmax=2)
ax1.set_ylabel('$p_x$ (a.u.)', size=Size,**nofont)
for label in ax1.get_yticklabels():
    label.set_fontname('Times New Roman')
for label in ax1.get_xticklabels():
    label.set_fontname('Times New Roman')
plt.tick_params(axis='both', labelsize=Size,bottom=True, top=False, labelbottom=0, left=True, labelleft=True)
ax1.text(-2.95, 1.34, '(a1)', fontsize = 1.1*Size, **nofont, color='white')
# ax1.text(2.3, 1.34, r'$\tau$=0 fs', fontsize = Size, **nofont, color='white')

ax3 = plt.subplot2grid((2, 5), (0, 3), colspan=2)
ax3.plot(spec0[:, 0] * 41300 / (2*pi), log(spec0[:, 1]), color = 'r', linewidth = 3)
ax3.set_xlim(-175,950)
ax3.set_ylim(-4.5,0.1)
ax3.set_yticks(linspace(-4, 0, 5))
ax3.set_yticklabels(('-4','-3','-2','-1','0'), size = Size, **nofont)
ax3.set_xticks(linspace(0, 750, 3))
ax3.set_ylabel('Amplitude (arb.u.)', size = Size, **nofont)
ax3.grid(True, linestyle = '-',color='black', alpha=0.1)
ax3.axvspan(-175, 175, facecolor='m', alpha=0.5)
ax3,axvline(x=375, lw=1.2, c='r', alpha=0.3, ls=":")
ax3,axvline(x=750, lw=1.2, c='b', alpha=0.3, ls=":")
ax4,axvline(x=0, lw=1.2, c='black', alpha=0.3, ls=":")
ax3.tick_params(axis='both', labelsize=Size,bottom=True, top=False, labelbottom=0, left=True, labelleft=True)
ax3.text(800, -0.4, '(a2)', fontsize = 1.1*Size, **nofont)
ax3.text(10, -4.3, 'THz', fontsize = 0.95*Size, **nofont)
ax3.text(270, -4.3, '800nm', fontsize = 0.95*Size, **nofont)
ax3.text(650, -4.3, '400nm', fontsize = 0.95*Size, **nofont)


ax2 = plt.subplot2grid((2, 5), (1, 0), colspan=3)
ax2.imshow(np.log10(spec_1), extent=[-3,3,0,1.5], aspect='auto',cmap=cm.jet, vmin=-10, vmax=2) 
ax2.set_xlabel('$p_z$ (a.u.)', size=Size,**nofont)
ax2.set_ylabel('$p_x$ (a.u.)', size=Size,**nofont)
for label in ax2.get_xticklabels():
    label.set_fontname('Times New Roman')
ax2.set_yticks(np.linspace(0, 1.5, 4))
ax2.set_yticklabels(('0.0','0.5','1.0'),**nofont)
plt.tick_params(axis='both', which='major', labelsize=Size)
ax2.text(-2.95, 1.34, '(b1)', fontsize = 1.1*Size, **nofont, color='white')
# ax2.text(2, 1.34, r'$\tau$=0.34 fs', fontsize = Size, **nofont, color='white')

ax4 = plt.subplot2grid((2, 5), (1, 3), colspan=2)
ax4.plot(spec1[:, 0] * 41300 / (2*pi), np.log(spec1[:, 1]), color = 'r', linewidth = 3)
ax4.set_xlim(-175,950)
ax4.set_ylim(-4.5,0.1)
ax4.set_yticks(linspace(-4, 0, 5))
ax4.set_yticklabels(('-4','-3','-2','-1','0'), size = Size, **nofont)
ax4.set_xticks(linspace(0, 750, 3))
ax4.set_xticklabels(('0','375','750'), size = Size, **nofont)
ax4.set_xlabel('Frequency (THz)', size = Size, **nofont)
ax4.set_ylabel('Amplitude (arb.u.)', size = Size, **nofont)
ax4.grid(True, linestyle = '-',color='black', alpha=0.1)
ax4.axvspan(-175, 175, facecolor='m', alpha=0.5)
ax4,axvline(x=375, lw=1.2, c='r', alpha=0.3, ls=":")
ax4,axvline(x=750, lw=1.2, c='b', alpha=0.3, ls=":")
ax4,axvline(x=0, lw=1.2, c='black', alpha=0.3, ls=":")
ax4.text(800, -0.41, '(b2)', fontsize = 1.1*Size, **nofont)
ax4.text(10, -4.3, 'THz', fontsize = 0.95*Size, **nofont)
ax4.text(270, -4.3, '800nm', fontsize = 0.95*Size, **nofont)
ax4.text(650, -4.3, '400nm', fontsize = 0.95*Size, **nofont)

plt.subplots_adjust(hspace=0.03)
plt.subplots_adjust(wspace=0.7)
plt.savefig('fig4/fig4.pdf',dpi=200, bbox_inches='tight')

# %%
figsize(38,7)
fig = figure()
ax1 = subplot2grid((1, 20), (0, 0),colspan = 14)
ax1.imshow(log10(spec_2), extent=[-3,3,0,1.5], cmap=cm.jet, vmin=-10, vmax=2)
ax1.set_xlabel('$p_z$ (a.u.)', size=30)
ax1.set_ylabel('$p_x$ (a.u.)', size=30)
Xscale=linspace(-3, 3, 7)
ax1.set_xticks(Xscale)
ax1.set_xticklabels(('-3','-2','-1','0','1','2','3'), size = 25)
Yscale=linspace(0, 1.5, 6)
ax1.set_yticks(Yscale)
ax1.set_yticklabels(('0','0.3','0.6','0.9','1.2','1.5'), size = 25)
ax1.text(-2.95, 1.35, '(a1)', fontsize = 30, color='w')
ax1.set_title(r'Momentum Distribution', size = 35)

ax2 = subplot2grid((1, 20), (0, 15), colspan = 3)
ax2.plot(spec2[:, 0] * 41300 / (2*pi), log(spec2[:, 1]), color = 'r', linewidth = 3)
Yscale=linspace(-4, 0, 5)
ax2.set_yticks(Yscale)
ax2.set_yticklabels(('-4','-3','-2','-1','0'), size = 25)
Xscale=linspace(0, 750, 3)
ax2.set_xticks(Xscale)
ax2.set_xticklabels(('0','375','750'), size = 25)
ax2.set_xlim(-180,950)
ax2.set_ylim(-4.3,0.1)
ax2.set_xlabel('Frequency (THz)', size = 30)
ax2.set_ylabel('Amplitude (arb.unit)', size = 30)
ax2.grid(True, linestyle = '-.')
ax2.axvspan(-180, 180, facecolor='silver', alpha=0.3)
ax2.axvspan(180, 575, facecolor='r', alpha=0.3)
ax2.axvspan(575, 950, facecolor='deepskyblue', alpha=0.3)
#ax3.axvspan(950, 1300, facecolor='darkviolet', alpha=0.3)
#ax2.text(-70, -4.2, 'THz', fontsize = 30)
#ax2.text(250, -4.2, '800nm', fontsize = 30)
#ax2.text(650, -4.2, '400nm', fontsize = 30)
ax2.text(-90, -4.2, 'THz', fontsize = 28)
ax2.text(190, -4.2, '800nm', fontsize = 28)
ax2.text(590, -4.2, '400nm', fontsize = 28)
#ax3.text(970, -4.2, '266nm', fontsize = 20)
ax2.text(-170, -0.25, '(a2)', fontsize = 35)
#legend = ax2.legend(loc='upper right', shadow=True, fontsize='large')
#legend.get_frame().set_alpha(0.2)
ax2.set_title('Spectrum', size = 35)

#savefig('Fig_SI',dpi=512, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Spectrum')
